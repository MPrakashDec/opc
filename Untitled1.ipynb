# %% [markdown]
# <a href="https://colab.research.google.com/github/MPrakashDec/opc/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/MPrakashDec/opc
# %cd opc
# !ls
# Out:
# Cloning into 'opc'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 40 (delta 12), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (40/40), 91.61 KiB | 2.04 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/opc
#  21March10Mar26000	   logger_ist.py
#  21March10Mar26000.py	   olddata_fetcher.py
#  backtest.py		   option_symbol.py
#  backtest_trades.csv	   python
#  backtest.zip		   README.md
#  calc_synthetic_26000.py  'Refining Backtesting Strategy.md'
#  config.py		   requirements.txt
#  data_fetcher.py	   test_1min_atm_exp2.py
#  deepseeknotes.txt	   test_1min_atm.py
#  deepseektest2.py	   test_26000_5min.py
#  deepseektest3.py	   test_5min_around_1245_2.py
#  deepseektest4.py	   test_5min_around_1245_3.py
#  deepseek_test.py	   test_5min_around_1245.py
#  dhan_margin.py		   test_atm6_range.py
# ...
